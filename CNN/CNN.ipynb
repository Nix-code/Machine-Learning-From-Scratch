# %%
# cifar data
from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense

# %%
# load datasets
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# %%
class_names = ["plane", "car", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# %%
# plot the result
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))

for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(train_images[i])
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
model = Sequential()

# %%
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)))

model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation='relu'))

model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,(3,3), activation='relu'))

# %%
model.add(layers.Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 30, 30, 32)        896
#
#  max_pooling2d_6 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 13, 13, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_18 (Conv2D)          (None, 4, 4, 64)          36928
#
#  flatten_4 (Flatten)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 64)                65600
#
#  dense_6 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, epochs=20, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/20
# 2023-02-01 22:46:55.718014: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 153600000 exceeds 10% of free system memory.
# 1563/1563 [==============================] - 43s 27ms/step - loss: 1.8266 - accuracy: 0.3730 - val_loss: 1.4093 - val_accuracy: 0.4936
# Epoch 2/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.3266 - accuracy: 0.5247 - val_loss: 1.2420 - val_accuracy: 0.5590
# Epoch 3/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.1665 - accuracy: 0.5876 - val_loss: 1.1541 - val_accuracy: 0.5953
# Epoch 4/20
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.0668 - accuracy: 0.6254 - val_loss: 1.2427 - val_accuracy: 0.5708
# Epoch 5/20
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.9768 - accuracy: 0.6592 - val_loss: 1.1767 - val_accuracy: 0.6046
# Epoch 6/20
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.9092 - accuracy: 0.6816 - val_loss: 1.0469 - val_accuracy: 0.6419
# Epoch 7/20
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.8454 - accuracy: 0.7064 - val_loss: 1.0208 - val_accuracy: 0.6605
# Epoch 8/20
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.7929 - accuracy: 0.7253 - val_loss: 1.0650 - val_accuracy: 0.6527
# Epoch 9/20
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.7466 - accuracy: 0.7404 - val_loss: 1.0876 - val_accuracy: 0.6501
# Epoch 10/20
#  371/1563 [======>.......................] - ETA: 27s - loss: 0.6737 - accuracy: 0.7646
