# %% [markdown]
# ### Table of Contents

# %% [markdown]
# #### 1. [The Basics](#content1)
#
# #### 2. [Creating DataFrame](#content2)
#
# #### 3. [Treating null values](#content3)
#
# #### 4. [Modify/Add new column(s).](#content4)
#
# #### 5. [Deleting columns](#content5)
#
# #### 6. [Renaming columns](#content6)
#
# #### 7.i. [Slicing DataFrame](#content7)
#
# #### 7.ii. [Slicing using iloc and loc](#content8)
#
# #### 8. [Adding a row](#content9)
#
# #### 9. [Dropping row(s)](#content10)
#
# #### 10. [Sorting](#content11)
#
# #### 11. [Joins](#content12)
#
# #### 12. [Groupby](#content13)

# %%
# import libraries
import pandas as pd
import numpy as np

# %%
# importing the data
df = pd.read_csv("titanic.csv")

# %% [markdown]
# <a id="content1"></a>
# ## 1. The Basics

# %%
# see the first 5 rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# last 5 rows
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# shape of the dataframe
# (n_samples, x features)
df.shape
# Out:
# (891, 12)

# %%
# list all the columns
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# rows index
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
# value with their counts in a particular columns
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# General description of the dataset
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <a id='content2'></a>
# ## 2. Creating DataFrame

# %%
# create an empty data frame
df_empty = pd.DataFrame()
df_empty.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# From dict
student_info = {'Name':['Nishant','Sandeep','Ranjeev','Baaje','Rahmat'],
                'Age':[22,23,24,45,25],
                'Subject':['Data science','AI','CITS','civil','CSE']}

df_student = pd.DataFrame(student_info).reset_index(drop=True)
df_student.head()
# Out:
#       Name  Age       Subject
# 0  Nishant   22  Data science
# 1  Sandeep   23            AI
# 2  Ranjeev   24          CITS
# 3    Baaje   45         civil
# 4   Rahmat   25           CSE

# %% [markdown]
# <a id='content3'></a>
# ## 3. Treating null values

# %%
# check if the dataframe has null value or not
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
## On a particular columns
df.Age.isna().sum()
# Out:
# 177

# %% [markdown]
# Null value imputation

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)
df["Age"].isna().sum()
# Out:
# 0

# %% [markdown]
# <a id="content4"></a>
# ## 4. Modify/Add new columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
## Male:0, female: 1

df["Sex"] = df["Sex"].map({"male":0,"female":1})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
### Finding First Name and Last name from Name columns

df["last_name"] = df["Name"].apply(lambda x: x.split(',')[0])
df["first_name"] = df["Name"].apply(lambda x: ' '.join(x.split(',')[1:]))

# %%
# sets to 1 for men in 3rd class
df['Third&Men'] = df.apply(lambda row: int(row['Pclass']==3 and row['Sex']=='0'), axis=1)

# %%
def findAgeGroup(age):
    if age < 18:
        return 1
    elif age >=18 and age<=40:
        return 2
    elif age >=40 and age <60:
        return 3
    else:
        return 4
df['Age_group'] = df['Age'].apply(lambda x: findAgeGroup(x))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          0          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          0          2

# %% [markdown]
# <a id='content5'></a>
# ## 5. Deleting columns

# %%
df = df.drop(['PassengerId'], axis=1)
df.head()
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund, Mr. Owen Harris    0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2         1       3                             Heikkinen, Miss. Laina    1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4         0       3                           Allen, Mr. William Henry    0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  last_name  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          0          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          0          2

# %% [markdown]
# <a id='content6'></a>
# ## 6.Renaming columns

# %%
df = df.rename({'Sex':'Gender','Name':'Full Name', 'last_name':'SurName','first_name':'Name'})

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund, Mr. Owen Harris    0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2         1       3                             Heikkinen, Miss. Laina    1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4         0       3                           Allen, Mr. William Henry    0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  last_name  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          0          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          0          2

# %% [markdown]
# <a id='content7'></a>
# ## 7. Slicing DataFrame

# %%
# all rows with pclass 3

df_third_class = df[df['Pclass']==3].reset_index(drop=True)

# %%
# Females with age > 60
df_aged = df[(df['Sex']=='1') & (df['Age'] > 60)].reset_index(drop=True)
df_aged
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, last_name, first_name, Third&Men, Age_group]
# Index: []

# %%
# selecting some columns

df1 = df[['Age','Sex','Ticket']]

# %%
# select numerial columns only
numerics = ['int16','int32','int64','float16','float32','float64']
df_num = df.select_dtypes(numerics)
df_num.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Third&Men  Age_group
# 0         0       3    0  22.0      1      0   7.2500          0          2
# 1         1       1    1  38.0      1      0  71.2833          0          2
# 2         1       3    1  26.0      0      0   7.9250          0          2
# 3         1       1    1  35.0      1      0  53.1000          0          2
# 4         0       3    0  35.0      0      0   8.0500          0          2

# %%
# categorical
df_cat = df.select_dtypes('object')
df_cat.head()
# Out:
#                                                 Name            Ticket Cabin  \
# 0                            Braund, Mr. Owen Harris         A/5 21171   NaN
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599   C85
# 2                             Heikkinen, Miss. Laina  STON/O2. 3101282   NaN
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803  C123
# 4                           Allen, Mr. William Henry            373450   NaN
#
#   Embarked  last_name                                   first_name
# 0        S     Braund                              Mr. Owen Harris
# 1        C    Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2        S  Heikkinen                                  Miss. Laina
# 3        S   Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4        S      Allen                            Mr. William Henry

# %% [markdown]
# <a id="content8"></a>
# ## 7.ii Slicing using iloc and loc

# %%
# first 100 rows and all cols

df_hund = df.iloc[:100,:]
df_hund.shape
# Out:
# (100, 15)

# %%
# first 250 rows with a subset of columns
df_sub = df.iloc[:250,1:8]

# %%
df_sub.head()
# Out:
#    Pclass                                               Name  Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    0  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0
# 2       3                             Heikkinen, Miss. Laina    1  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0
# 4       3                           Allen, Mr. William Henry    0  35.0
#
#    SibSp  Parch            Ticket
# 0      1      0         A/5 21171
# 1      1      0          PC 17599
# 2      0      0  STON/O2. 3101282
# 3      1      0            113803
# 4      0      0            373450

# %%
df_sub4 = df.loc[(df['Age']>50),['Sex','Age']]
df_sub4
# Out:
#      Sex   Age
# 6      0  54.0
# 11     1  58.0
# 15     1  55.0
# 33     0  66.0
# 54     0  65.0
# ..   ...   ...
# 820    1  52.0
# 829    1  62.0
# 851    0  74.0
# 857    0  51.0
# 879    1  56.0
#
# [64 rows x 2 columns]

# %% [markdown]
# <a id="content9"></a>
# ## 8. Adding a row

# %%
row=dict({'Age':24,'Name':'Peter','Survived':'Y'})
df = df.append(row, ignore_index=True)
df.tail()
# Out:
# /tmp/ipykernel_33695/484250108.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
#     Survived  Pclass                                      Name  Sex  \
# 887        1     1.0              Graham, Miss. Margaret Edith  1.0
# 888        0     3.0  Johnston, Miss. Catherine Helen "Carrie"  1.0
# 889        1     1.0                     Behr, Mr. Karl Howell  0.0
# 890        0     3.0                       Dooley, Mr. Patrick  0.0
# 891        Y     NaN                                     Peter  NaN
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked last_name  \
# 887  19.000000    0.0    0.0      112053  30.00   B42        S    Graham
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S  Johnston
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      Behr
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q    Dooley
# 891  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
#
#                           first_name  Third&Men  Age_group
# 887             Miss. Margaret Edith        0.0        2.0
# 888   Miss. Catherine Helen "Carrie"        0.0        2.0
# 889                  Mr. Karl Howell        0.0        2.0
# 890                      Mr. Patrick        0.0        2.0
# 891                              NaN        NaN        NaN

# %% [markdown]
# <a id="content10"></a>
# ## 9. Dropping row(s)

# %%
df = df.drop(df.index[-1], axis=0)
df.tail()
# Out:
#     Survived  Pclass                                      Name  Sex  \
# 886        0     2.0                     Montvila, Rev. Juozas  0.0
# 887        1     1.0              Graham, Miss. Margaret Edith  1.0
# 888        0     3.0  Johnston, Miss. Catherine Helen "Carrie"  1.0
# 889        1     1.0                     Behr, Mr. Karl Howell  0.0
# 890        0     3.0                       Dooley, Mr. Patrick  0.0
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked last_name  \
# 886  27.000000    0.0    0.0      211536  13.00   NaN        S  Montvila
# 887  19.000000    0.0    0.0      112053  30.00   B42        S    Graham
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S  Johnston
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      Behr
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q    Dooley
#
#                           first_name  Third&Men  Age_group
# 886                      Rev. Juozas        0.0        2.0
# 887             Miss. Margaret Edith        0.0        2.0
# 888   Miss. Catherine Helen "Carrie"        0.0        2.0
# 889                  Mr. Karl Howell        0.0        2.0
# 890                      Mr. Patrick        0.0        2.0

# %%
df.head()
# Out:
#   Survived  Pclass                                               Name  Sex  \
# 0        0     3.0                            Braund, Mr. Owen Harris  0.0
# 1        1     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  1.0
# 2        1     3.0                             Heikkinen, Miss. Laina  1.0
# 3        1     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  1.0
# 4        0     3.0                           Allen, Mr. William Henry  0.0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  last_name  \
# 0  22.0    1.0    0.0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0    1.0    0.0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0    0.0    0.0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0    1.0    0.0            113803  53.1000  C123        S   Futrelle
# 4  35.0    0.0    0.0            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third&Men  Age_group
# 0                              Mr. Owen Harris        0.0        2.0
# 1   Mrs. John Bradley (Florence Briggs Thayer)        0.0        2.0
# 2                                  Miss. Laina        0.0        2.0
# 3           Mrs. Jacques Heath (Lily May Peel)        0.0        2.0
# 4                            Mr. William Henry        0.0        2.0

# %% [markdown]
# <a id="content11"></a>
# ## 10. Sorting

# %%
# sorting age by decreasing order
df= df.sort_values(by=['Age'], ascending=False)
df.head()
# Out:
#     Survived  Pclass                                  Name  Sex   Age  SibSp  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson  0.0  80.0    0.0
# 851        0     3.0                   Svensson, Mr. Johan  0.0  74.0    0.0
# 96         0     1.0             Goldschmidt, Mr. George B  0.0  71.0    0.0
# 493        0     1.0               Artagaveytia, Mr. Ramon  0.0  71.0    0.0
# 116        0     3.0                  Connors, Mr. Patrick  0.0  70.5    0.0
#
#      Parch    Ticket     Fare Cabin Embarked     last_name  \
# 630    0.0     27042  30.0000   A23        S     Barkworth
# 851    0.0    347060   7.7750   NaN        S      Svensson
# 96     0.0  PC 17754  34.6542    A5        C   Goldschmidt
# 493    0.0  PC 17609  49.5042   NaN        C  Artagaveytia
# 116    0.0    370369   7.7500   NaN        Q       Connors
#
#                      first_name  Third&Men  Age_group
# 630   Mr. Algernon Henry Wilson        0.0        4.0
# 851                   Mr. Johan        0.0        4.0
# 96                 Mr. George B        0.0        4.0
# 493                   Mr. Ramon        0.0        4.0
# 116                 Mr. Patrick        0.0        4.0

# %% [markdown]
# <a id="content12"></a>
# ## 11. Joins

# %% [markdown]
# Let's create two separate data frames and try all 5 (Cross,Inner, Left, Right,and Outer Joins).

# %%
sno = [i+1 for i in range(100)]
marks = np.random.randint(100, size=100)
marks_df =pd.DataFrame({'sno':sno,'Marks':marks})
marks_df.head()
# Out:
#    sno  Marks
# 0    1     75
# 1    2     54
# 2    3     50
# 3    4     37
# 4    5     92

# %%
sno = [i+1 for i in range(100)]
age = np.random.randint(100, size=100)
age_df = pd.DataFrame({'sno':sno,'Age':age})
age_df.head()
# Out:
#    sno  Age
# 0    1   60
# 1    2   27
# 2    3   42
# 3    4   15
# 4    5   45

# %%
## Cross join

# %%
cross_join = pd.merge(marks_df, age_df, how='cross')

# %%
# inner join
inner_join = pd.merge(marks_df, age_df, how='inner', on='sno')
inner_join.head()
# Out:
#    sno  Marks  Age
# 0    1     75   60
# 1    2     54   27
# 2    3     50   42
# 3    4     37   15
# 4    5     92   45

# %%
# left and right outer joins

# %%
age_df.loc[len(age_df.index)]={'Sno':101,'Age':23}
age_df.loc[len(age_df.index)]={'Sno':102,'Age':27}
age_df.loc[len(age_df.index)]={'Sno':104,'Age':29}
age_df.loc[len(age_df.index)]={'Sno':103,'Age':32}
age_df.loc[len(age_df.index)]={'Sno':105,'Age':53}

# %%
left_join = pd.merge(age_df, marks_df, how='left',on='sno')
left_join.tail()
# Out:
#      sno  Age  Marks
# 100  NaN   23    NaN
# 101  NaN   27    NaN
# 102  NaN   29    NaN
# 103  NaN   32    NaN
# 104  NaN   53    NaN

# %% [markdown]
#  outer code is same as inner

# %% [markdown]
# <a id="content13"></a>
# ## 12. Groupby
#
# Let's get back to our titanic dataset.

# %%
df.head()
# Out:
#     Survived  Pclass                                  Name  Sex   Age  SibSp  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson  0.0  80.0    0.0
# 851        0     3.0                   Svensson, Mr. Johan  0.0  74.0    0.0
# 96         0     1.0             Goldschmidt, Mr. George B  0.0  71.0    0.0
# 493        0     1.0               Artagaveytia, Mr. Ramon  0.0  71.0    0.0
# 116        0     3.0                  Connors, Mr. Patrick  0.0  70.5    0.0
#
#      Parch    Ticket     Fare Cabin Embarked     last_name  \
# 630    0.0     27042  30.0000   A23        S     Barkworth
# 851    0.0    347060   7.7750   NaN        S      Svensson
# 96     0.0  PC 17754  34.6542    A5        C   Goldschmidt
# 493    0.0  PC 17609  49.5042   NaN        C  Artagaveytia
# 116    0.0    370369   7.7500   NaN        Q       Connors
#
#                      first_name  Third&Men  Age_group
# 630   Mr. Algernon Henry Wilson        0.0        4.0
# 851                   Mr. Johan        0.0        4.0
# 96                 Mr. George B        0.0        4.0
# 493                   Mr. Ramon        0.0        4.0
# 116                 Mr. Patrick        0.0        4.0

# %%
groups = df.groupby(['Pclass'])

groups.get_group(1)
# Out:
#     Survived  Pclass                                  Name  Sex    Age  SibSp  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson  0.0  80.00    0.0
# 96         0     1.0             Goldschmidt, Mr. George B  0.0  71.00    0.0
# 493        0     1.0               Artagaveytia, Mr. Ramon  0.0  71.00    0.0
# 745        0     1.0          Crosby, Capt. Edward Gifford  0.0  70.00    1.0
# 456        0     1.0             Millet, Mr. Francis Davis  0.0  65.00    0.0
# ..       ...     ...                                   ...  ...    ...    ...
# 435        1     1.0             Carter, Miss. Lucile Polk  1.0  14.00    1.0
# 802        1     1.0   Carter, Master. William Thornton II  0.0  11.00    1.0
# 445        1     1.0             Dodge, Master. Washington  0.0   4.00    0.0
# 297        0     1.0          Allison, Miss. Helen Loraine  1.0   2.00    1.0
# 305        1     1.0        Allison, Master. Hudson Trevor  0.0   0.92    1.0
#
#      Parch     Ticket      Fare    Cabin Embarked     last_name  \
# 630    0.0      27042   30.0000      A23        S     Barkworth
# 96     0.0   PC 17754   34.6542       A5        C   Goldschmidt
# 493    0.0   PC 17609   49.5042      NaN        C  Artagaveytia
# 745    1.0  WE/P 5735   71.0000      B22        S        Crosby
# 456    0.0      13509   26.5500      E38        S        Millet
# ..     ...        ...       ...      ...      ...           ...
# 435    2.0     113760  120.0000  B96 B98        S        Carter
# 802    2.0     113760  120.0000  B96 B98        S        Carter
# 445    2.0      33638   81.8583      A34        S         Dodge
# 297    2.0     113781  151.5500  C22 C26        S       Allison
# 305    2.0     113781  151.5500  C22 C26        S       Allison
#
#                        first_name  Third&Men  Age_group
# 630     Mr. Algernon Henry Wilson        0.0        4.0
# 96                   Mr. George B        0.0        4.0
# 493                     Mr. Ramon        0.0        4.0
# 745          Capt. Edward Gifford        0.0        4.0
# 456             Mr. Francis Davis        0.0        4.0
# ..                            ...        ...        ...
# 435             Miss. Lucile Polk        0.0        1.0
# 802   Master. William Thornton II        0.0        1.0
# 445            Master. Washington        0.0        1.0
# 297           Miss. Helen Loraine        0.0        1.0
# 305         Master. Hudson Trevor        0.0        1.0
#
# [216 rows x 15 columns]

# %%
# Average age per Pclass
df_grp1 = df.groupby(['Pclass'])
df_grp1['Age'].mean()
# Out:
# Pclass
# 1.0    37.048118
# 2.0    29.866958
# 3.0    26.403259
# Name: Age, dtype: float64

# %%
## Min max

df_grp1['Age'].min()
# Out:
# Pclass
# 1.0    0.92
# 2.0    0.67
# 3.0    0.42
# Name: Age, dtype: float64

# %%
df_grp1['Age'].max()
# Out:
# Pclass
# 1.0    80.0
# 2.0    70.0
# 3.0    74.0
# Name: Age, dtype: float64

# %%
df_grp1['Age'].count()
# Out:
# Pclass
# 1.0    216
# 2.0    184
# 3.0    491
# Name: Age, dtype: int64

# %%
param = {'Age': lambda x: np.mean(x)}

# %%
# using agg() function
df_grp2 = df.groupby(['Pclass']).agg(param)

# %%
df_grp2
# Out:
#               Age
# Pclass
# 1.0     37.048118
# 2.0     29.866958
# 3.0     26.403259

# %%
## Min. Max, count, sum, for each Pclass using


df_grp3 = df.groupby(['Pclass']).agg({'Age':'min'}).rename(columns={'Age':'Min Age'})
df_grp3
# Out:
#         Min Age
# Pclass
# 1.0        0.92
# 2.0        0.67
# 3.0        0.42

# %%
# Name of the passengers in that class

df_grp4 = df.groupby(['Pclass']).agg({'Name': lambda x: ' '.join(x)})

# %%
df_grp4
# Out:
#                                                      Name
# Pclass
# 1.0     Barkworth, Mr. Algernon Henry Wilson Goldschmi...
# 2.0     Mitchell, Mr. Henry Michael Wheadon, Mr. Edwar...
# 3.0     Svensson, Mr. Johan Connors, Mr. Patrick Duane...
